# %%
from IPython.display import Image

# %%
Image(filename='/Users/ruizhihao/Desktop/TRAINing/Heap1.png')

# %%
Image(filename='/Users/ruizhihao/Desktop/TRAINing/Heap11.png')

# %%
Image(filename='/Users/ruizhihao/Desktop/TRAINing/Heap2.png')

# %%
Image(filename='/Users/ruizhihao/Desktop/TRAINing/Heap21.png')

# %% [markdown]
# 复杂度O(Nlog(k))

# %%
Image(filename='/Users/ruizhihao/Desktop/TRAINing/Heap22.png')

# %% [markdown]
# Question 4
#
# Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid. An input string is valid if: open brackets must be closed by the same type of brackets and open brackets must be closed in the correct order.

# %%
def isValid(self, s):
    stack =[]
    mapping ={")":"(","]":"[]","}":"{"} 
    for char in s:
        if char in mapping:
            top_element = stack.pop() if stack else '#'
            if mapping[char] != top_element:
                return False
            else:
                stack.append(char)
    return not stack

# %%
A =[1,2,3]
len(A)
# Out:
# 3
